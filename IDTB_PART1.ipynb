# %% [markdown]
# **DATA ACCUMULATION AND REMOVAL OF MISSING DATA**

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('Cyclic GMP-AMP synthase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#     cross_references          organism  \
# 0                 []      Homo sapiens
# 1                 []      Mus musculus
# 2                 []      Homo sapiens
# 3                 []      Mus musculus
# 4                 []      Homo sapiens
# ..               ...               ...
# 750               []      Homo sapiens
# 751               []      Homo sapiens
# 752               []          Bacteria
# 753               []      Homo sapiens
# 754               []  Escherichia coli
#
#                                              pref_name  score  \
# 0                              Cyclic GMP-AMP synthase   37.0
# 1                              Cyclic GMP-AMP synthase   37.0
# 2                                Phosphodiesterase 11A   29.0
# 3    Dual 3',5'-cyclic-AMP and -GMP phosphodiestera...   29.0
# 4                       Phosphodiesterase; PDE3 & PDE4   28.0
# ..                                                 ...    ...
# ...

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL4105728'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None   Not Determined
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 590  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 591  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 592  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 593  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 594  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id                                activity_properties  \
# ...

# %%
df.to_csv('cGAS_idtb_bioactivity_data_raw.csv', index=False)

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-13-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# 5                                                 None             None
# ..                                                 ...              ...
# 590  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 591  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 592  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 593  {'action_type': 'INHIBITOR', 'description': 'N...             None
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 374

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# 5                                                 None             None
# ..                                                 ...              ...
# 580  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 581  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 582  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 584  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 588  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id activity_properties assay_chembl_id  \
# ...

# %% [markdown]
# **DATA PREPROCESSING OF BIOACTIVITY DATA**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL4103560               O=C(NCCO)c1cnn2c(O)cc(-c3ccccc3)nc12
# 1        CHEMBL4085628                 CNC(=O)c1cnn2c(O)cc(-c3ccccc3)nc12
# 3         CHEMBL577784  O=C(NCCCNc1nc(Nc2cccc(NC(=O)N3CCCC3)c2)ncc1I)c...
# 4        CHEMBL4096573  O=C(N[C@H]1CCCC[C@H]1C(=O)O)c1cnn2c(O)cc(-c3cc...
# 5        CHEMBL4084664       C[C@@H](CO)NC(=O)c1cnn2c(O)cc(-c3ccccc3)nc12
# ..                 ...                                                ...
# 580      CHEMBL5203275           O=C1N=C(N2CCCCC2)S/C1=C1/C(=O)Nc2ccccc21
# 581      CHEMBL5205793           O=C(Nc1ccc(Cl)cn1)c1[nH]ncc1[N+](=O)[O-]
# 582      CHEMBL5179510             COCC(=O)N1CCc2[nH]c3c(Cl)cc(Cl)cc3c2C1
# 584      CHEMBL5174318  Cn1cc(-c2cc(Cl)c(Cl)c3[nH]c4c(c23)CN(C(=O)CO)C...
# 588         CHEMBL1535                 CCN(CCO)CCCC(C)Nc1ccnc2cc(Cl)ccc12
#
#     standard_value
# 0          19000.0
# 1          69000.0
# ...

# %%
df3.to_csv('cGAS_idtb02_bioactivity_data_preprocessed.csv', index=False)

# %%
df4 = pd.read_csv('cGAS_idtb02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL4103560               O=C(NCCO)c1cnn2c(O)cc(-c3ccccc3)nc12
# 1        CHEMBL4085628                 CNC(=O)c1cnn2c(O)cc(-c3ccccc3)nc12
# 2         CHEMBL577784  O=C(NCCCNc1nc(Nc2cccc(NC(=O)N3CCCC3)c2)ncc1I)c...
# 3        CHEMBL4096573  O=C(N[C@H]1CCCC[C@H]1C(=O)O)c1cnn2c(O)cc(-c3cc...
# 4        CHEMBL4084664       C[C@@H](CO)NC(=O)c1cnn2c(O)cc(-c3ccccc3)nc12
# ..                 ...                                                ...
# 369      CHEMBL5203275           O=C1N=C(N2CCCCC2)S/C1=C1/C(=O)Nc2ccccc21
# 370      CHEMBL5205793           O=C(Nc1ccc(Cl)cn1)c1[nH]ncc1[N+](=O)[O-]
# 371      CHEMBL5179510             COCC(=O)N1CCc2[nH]c3c(Cl)cc(Cl)cc3c2C1
# 372      CHEMBL5174318  Cn1cc(-c2cc(Cl)c(Cl)c3[nH]c4c(c23)CN(C(=O)CO)C...
# 373         CHEMBL1535                 CCN(CCO)CCCC(C)Nc1ccnc2cc(Cl)ccc12
#
#      standard_value         class
# 0           19000.0      inactive
# ...

# %%
df5.to_csv('cGAS_idtb03_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip *.csv
# Out:
#   adding: cGAS_idtb02_bioactivity_data_preprocessed.csv (deflated 82%)
#   adding: cGAS_idtb03_bioactivity_data_curated.csv (deflated 84%)
#   adding: cGAS_idtb_bioactivity_data_raw.csv (deflated 94%)

# %%
! ls -l
# Out:
# total 432
# -rw-r--r-- 1 root root  31241 Feb 11 16:43 acetylcholinesterase.zip
# -rw-r--r-- 1 root root  27030 Feb 11 16:40 cGAS_idtb02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  30162 Feb 11 16:43 cGAS_idtb03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root 341220 Feb 11 16:29 cGAS_idtb_bioactivity_data_raw.csv
# drwxr-xr-x 1 root root   4096 Feb  7 14:20 sample_data
